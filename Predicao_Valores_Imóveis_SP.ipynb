# %% [markdown]
# <a href="https://colab.research.google.com/github/KaueAbbe/ImersaoDados/blob/main/Predicao_Valores_Im%C3%B3veis_SP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color=darkblue size = 10> Imersão Dados 04</font>
#
# Autor: Kaue Hermann Abbehausen
#
# <b>Objetivo:</b> Analisar dados de imóveis a venda no Estado de São Paulo. O dataset foi obtido no Kaggle e foi alterado pelos instrutores.

# %% [markdown]
# ## Aula 1: Leitura e Prévia Organização dos Dados
#
# <b>Objetivos:</b>
# 1. Utilizar o pandas para ler os dados e fazer algumas organizações nele.
# 2. Retirar valores estatísticos (média, mediana, soma)
# 3. Realizar alguns gráficos com Pandas

# %%
import pandas as pd
import numpy as np
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                    Rua                Bairro     Cidade  \
# 8306       Rua Cristóvão Camargo, 200          Vila Araguaia  São Paulo
# 7678                               NaN  Parque dos Príncipes  São Paulo
# 7436                     Rua Luís Góis          Mirandópolis  São Paulo
# 460              Rua Senador Vergueiro           Santo Amaro  São Paulo
# 5363      Rua Visconde de Sabóia, 315       Vila Macedópolis  São Paulo
# 1519  Rua Engenheiro Guimarães Valadão         Cidade Jardim  São Paulo
# 5028           Praça Pinheiro da Cunha              Ipiranga  São Paulo
# 3445                               NaN     Alto de Pinheiros  São Paulo
# 2958            Rua Maestro Elias Lobo       Jardim Paulista  São Paulo
# 6471               Rua Silveira Campos               Cambuci  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 8306       135        3          1      1
# 7678       898        4          8     10
# 7436       202        2          1      1
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# ### Desafios dos Instrutores

# %% [markdown]
# ### 1. Realizar a média da metragem para cara um dos bairros (Paulo)

# %%
bairros= dados.groupby(by = 'Bairro')[['Metragem','Quartos','Banheiros','Vagas']].mean()
bairros['Metragem']
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
bairros['Metragem'].nlargest(5)
# Out:
# Bairro
# Sítio Represa          37000.000000
# Vila Castelo            2850.000000
# Jardim Guedala          2486.640199
# Jardim das Camélias     1700.000000
# Chácara Flora           1260.727273
# Name: Metragem, dtype: float64

# %%
bairros['Metragem'].nlargest(10).plot.bar()

# %% [markdown]
# **Comentários Rápidos:** Há uma grande discrepância no valor da média de metragem para Sítio Represa

# %% [markdown]
# ### 2. 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago).
# Vamos fazer por 3 formas:
# 1. Agrupamento(groupby)
# 2. Seleção True ou False
# 3. seleção por querys

# %%
bairros1 = dados.groupby(by = 'Bairro')[['Metragem','Quartos','Banheiros','Vagas']].mean()
bairros1
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %%
nome_bairro = ['Aclimação']  #Vamos selecionar este bairro para exemplificar
bairro2 = dados[dados['Bairro'].isin(nome_bairro)]
bairro2
# Out:
#                                              Rua     Bairro     Cidade  \
# 269                              Rua Ximbó, 410   Aclimação  São Paulo
# 670                          Rua Alabastro, 151   Aclimação  São Paulo
# 1265                           Rua Carlos Chagas  Aclimação  São Paulo
# 1287                        Rua Doutor João Maia  Aclimação  São Paulo
# 1347                        Rua Doutor João Maia  Aclimação  São Paulo
# ...                                          ...        ...        ...
# 9260  Rua Doutor Rafael Caramuru Lanzelloti, 77   Aclimação  São Paulo
# 9366                                Rua Baturité  Aclimação  São Paulo
# 9418                           Rua André Gouveia  Aclimação  São Paulo
# 9539                                    Rua Rubi  Aclimação  São Paulo
# 9776                       Rua Oscar Guanabarino  Aclimação  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# ...

# %%
bairros3 = dados.query('Bairro == "Aclimação"')
bairros3.head(10)
# Out:
#                                   Rua     Bairro     Cidade  Metragem  \
# 269                   Rua Ximbó, 410   Aclimação  São Paulo       140
# 670               Rua Alabastro, 151   Aclimação  São Paulo       129
# 1265                Rua Carlos Chagas  Aclimação  São Paulo       280
# 1287             Rua Doutor João Maia  Aclimação  São Paulo       380
# 1347             Rua Doutor João Maia  Aclimação  São Paulo       385
# 1663  Rua Doutor Numa Pereira do Vale  Aclimação  São Paulo       336
# 1763  Rua Doutor Numa Pereira do Vale  Aclimação  São Paulo       341
# 2044                    Rua Maranduba  Aclimação  São Paulo       160
# 2141                    Rua Maranduba  Aclimação  São Paulo       165
# 2369                      Rua Maracaí  Aclimação  São Paulo       420
#
#       Quartos  Banheiros  Vagas                                  Valor
# 269         4          3      4                             R$ 800.000
# ...

# %% [markdown]
# ### 3. Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

# %%
dados['Metragem'].nsmallest(500).plot.hist(bins = 20)

# %%
dados.groupby('Quartos')['Quartos'].count()[:8].plot.bar()

# %%
dados.groupby('Quartos')['Quartos'].mean()[:].plot.box()

# %%
dados[['Quartos','Banheiros']].boxplot()

# %%
dados['Metragem'].nsmallest(8000).plot.density()

# %%
dados['Metragem'].nsmallest(8000).plot.kde()

# %% [markdown]
# Tanto o plot.density() quanto o plot.kde() fazem gráficos de Kernal Density Estimation. KDE é uma estimativa não paramétrica da função probabilidade de densidade de uma variável randômica.
#
# * **Referência: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.kde.html**

# %% [markdown]
# ### 4. Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
# Existem duas formas de pegar estatísticas: Pedindo a estatística específica e usando o describe.
#
# | Quero Fazer   | Uso   |
# |---------|-----------|
# | média   | .mean()   |
# | Mediana | .median() |
# | Soma    | .sum()    |
# | máximo  | .max()    |
# | mínimo  |.min()     |
# | Desvio Padrão  | .std()    |
# | Variância  |.var()     |
# | Valor Absoluto  |.abs()     |
#
# * **Apply: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html**
# * **Describe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html**

# %%
# Pedindo a estatística
dados[['Banheiros','Metragem','Quartos']].mean()
# Out:
# Banheiros      3.879097
# Metragem     442.300659
# Quartos        3.483114
# dtype: float64

# %%
#Pedindo mais de ao mesmo tempo
dados[['Banheiros','Metragem','Quartos']].apply({'mean','median','max','min'})
# Out:
#         Banheiros       Metragem    Quartos
# min      1.000000      10.000000   1.000000
# mean     3.879097     442.300659   3.483114
# median   4.000000     290.000000   3.000000
# max     40.000000  750000.000000  16.000000

# %%
#Aplicando estatística com Describe
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# A mediana nesta forma do describe é representado pelo 50%, que faz parte dos quartis. Os quartis dividem o dataset, por exemplo, 25% é o valor da divisão do primeiro quarto (1/4) do dataset, assim como a mediana é o valor do meio.

# %% [markdown]
# ### 5. Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head(10)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 6        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7     Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8         Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                      Rua Tapaji         Vila Alpina  São Paulo       114
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# ...

# %% [markdown]
# 1. Vamos primeiro fazer uma seleção pra ver somente os dados em que faltam o nome da rua

# %%
valores_missing = dados[dados['Rua'].isna()]
valores_missing
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...

# %%
valores_missing['Bairro'].unique()
# Out:
# array(['Jardim Morumbi', 'Jardim Luzitânia', 'Parque da Lapa',
#        'Chácara Santo Antônio (Zona Sul)', 'Jardim Guedala',
#        'Vila Arriete', 'Alto de Pinheiros', 'Planalto Paulista',
#        'Vila Moinho Velho', 'Brooklin Paulista', 'Sumaré',
#        'Jardim Paulista', 'Vila Gustavo', 'Jardim Trussardi',
#        'Vila Madalena', 'Jardim dos Estados', 'Vila Santos',
#        'Jardim Europa', 'Butantã', 'Jardim Paulistano',
#        'Jardim Petrópolis', 'Vila Mariana', 'Vila Aparecida', 'Siciliano',
#        'Alto da Lapa', 'Jardim da Glória', 'Morumbi', 'Vila Ida',
#        'Cidade Jardim', 'Cidade Dutra', 'Água Fria', 'Parque Boturussu',
#        'Belenzinho', 'Vila Sônia', 'Jardim Panorama', 'Jardim Ampliação',
#        'Lauzane Paulista', 'Vila Sabrina', 'Vila Olímpia',
#        'Jardim Franca', 'Jardim Sílvia (Zona Oeste)', 'Santo Amaro',
#        'Mooca', 'Jardim América', 'Interlagos', 'Pacaembu',
#        'Jardim Santo Amaro', 'Vila Matilde', 'Vila Prudente',
# ...

# %%
dados[dados['Bairro'].isin(['',' '])]
# Out:
# Empty DataFrame
# Columns: [Rua, Bairro, Cidade, Metragem, Quartos, Banheiros, Vagas, Valor]
# Index: []

# %% [markdown]
# ### Desafios Pessoais

# %% [markdown]
# ### Conseguir alterar o valor do preço e realizar uma média

# %%
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados['Valor'].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados[['Moeda','Valor_Venda','Tipo']] = dados['Valor'].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_Venda  Tipo
# 0        4          8      6  R$ 7.000.000    R$   7.000.000  None
# 1        4          4      4  R$ 3.700.000    R$   3.700.000  None
# 2        4          3      2    R$ 380.000    R$     380.000  None
# 3        3          2      4    R$ 685.000    R$     685.000  None
# 4        3          2      2    R$ 540.000    R$     540.000  None

# %%
dados_venda = dados[dados['Tipo'].isnull()]

# %%
dados_venda['Valor_Venda'] = dados_venda['Valor_Venda'].str.replace('.','').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_venda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rua          6107 non-null   object
#  1   Bairro       9146 non-null   object
#  2   Cidade       9156 non-null   object
#  3   Metragem     9156 non-null   int64
#  4   Quartos      9156 non-null   int64
#  5   Banheiros    9156 non-null   int64
#  6   Vagas        9156 non-null   int64
#  7   Valor        9156 non-null   object
#  8   Moeda        9156 non-null   object
#  9   Valor_Venda  9156 non-null   float64
#  10  Tipo         0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %%
dados_venda.drop('Valor', axis = 1, inplace = True)
dados_venda.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda  Valor_Venda  Tipo
# 0        4          8      6    R$    7000000.0  None
# 1        4          4      4    R$    3700000.0  None
# ...

# %%
dados_venda['Valor_Venda'].mean()
# Out:
# 3052202.9554390563

# %% [markdown]
# ## Aula 02
# <b>Objetivos:</b>
#
# 1. Criar colunas no Dataset
# 2. Utilizar seaborn, matplotlib para visualizar gráficos

# %% [markdown]
# ### Desafios dos instrutores 2
# ### 1. Criar uma escala de valores em milhões

# %%
dados_venda['Valor_Venda'].max()
# Out:
# 65000000.0

# %% [markdown]
# A escala funciona indo de 0 a 6.5. Sendo 1 igual a 1 milhão

# %%
lista =[] 
for valor in dados_venda['Valor_Venda'].values:
  lista.append((6.5/dados_venda['Valor_Venda'].max()) * valor)

# %%
dados_venda['Valor_venda_escala'] =  lista
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_venda.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda  Valor_Venda  Tipo  Valor_venda_escala
# 0        4          8      6    R$    7000000.0  None              0.7000
# 1        4          4      4    R$    3700000.0  None              0.3700
# 2        4          3      2    R$     380000.0  None              0.0380
# 3        3          2      4    R$     685000.0  None              0.0685
# 4        3          2      2    R$     540000.0  None              0.0540

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data = dados_venda, x = 'Valor_venda_escala')

# %% [markdown]
# ### 2. Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala) em conjunto com Explorar as bibliotecas de visualizações e colocar as suas conclusão

# %%
sns.set()
plt.figure(figsize=(10, 8))

cores = ['red' for i in range(0,10000)]
ax = sns.histplot(data = dados_venda, x = "Valor_venda_escala", kde = False, color = 'blue')
ax.set_title("Histograma Valor de Imóveis em São Paulo",fontsize = 18 )
ax.set_xlabel('Valor do Imóvel(em milhares)',fontsize = 16)
ax.set_xticklabels([0,200,400,600,800,1000])
ax.set_ylabel('Quantidade de Imóveis',fontsize = 16)

ax.text(s ='Maior parte dos Imóveis estão com \n valor abaixo de 400 Milhões',x = 0.4, y = 600,
         horizontalalignment='center', size='medium', color='black', weight='semibold')

plt.xlim((0, 1))
plt.show()

# %% [markdown]
# ### 3. Preço do metro quadrado por bairro e plotar em um gráfico ideal

# %%
valor_metro_bairro = dados_venda[~dados_venda['Bairro'].isnull()].groupby('Bairro')[['Metragem','Valor_Venda','Valor_venda_escala']].mean()
valor_metro_bairro.head()
# Out:
#                      Metragem   Valor_Venda  Valor_venda_escala
# Bairro
# Aclimação          246.164557  1.763200e+06            0.176320
# Alto da Boa Vista  418.875000  2.391250e+06            0.239125
# Alto da Lapa       299.250000  2.083169e+06            0.208317
# Alto da Mooca      270.050000  1.184170e+06            0.118417
# Alto de Pinheiros  429.853659  4.782699e+06            0.478270

# %%
valor_metro_bairro['Valor_Venda'].nlargest(5).index
# Out:
# Index(['Jardim América', 'Jardim Teresa', 'Chácara Flora', 'Retiro Morumbi',
#        'Jardim Europa'],
#       dtype='object', name='Bairro')

# %%
valor_metro_bairro.reset_index(inplace = True)
valor_metro_bairro
# Out:
#                 Bairro    Metragem   Valor_Venda  Valor_venda_escala
# 0            Aclimação  246.164557  1.763200e+06            0.176320
# 1    Alto da Boa Vista  418.875000  2.391250e+06            0.239125
# 2         Alto da Lapa  299.250000  2.083169e+06            0.208317
# 3        Alto da Mooca  270.050000  1.184170e+06            0.118417
# 4    Alto de Pinheiros  429.853659  4.782699e+06            0.478270
# ..                 ...         ...           ...                 ...
# 692    Vila Água Funda  152.200000  6.520000e+05            0.065200
# 693        Água Branca  173.583333  1.226500e+06            0.122650
# 694          Água Fria  165.416667  9.270833e+05            0.092708
# 695         Água Funda  139.000000  5.450000e+05            0.054500
# 696          Água Rasa  186.166667  7.161667e+05            0.071617
#
# [697 rows x 4 columns]

# %%
bairros_caros = valor_metro_bairro[valor_metro_bairro['Bairro'].isin(['Jardim América', 'Jardim Teresa', 'Chácara Flora', 'Retiro Morumbi',
       'Jardim Europa'])]
bairros_caros
# Out:
#              Bairro     Metragem   Valor_Venda  Valor_venda_escala
# 40    Chácara Flora  1251.444444  1.350000e+07            1.350000
# 103  Jardim América   646.310924  1.642760e+07            1.642760
# 155   Jardim Europa   566.180952  1.149606e+07            1.149606
# 277   Jardim Teresa   648.333333  1.483667e+07            1.483667
# 405  Retiro Morumbi  1136.391304  1.200261e+07            1.200261

# %%
plt.figure(figsize=(10, 8))

ax = sns.barplot(data = bairros_caros, x = "Bairro",y='Valor_Venda', color = 'blue')
ax.set_title("Barras dos 5 mais caros Bairros de São Paulo",fontsize = 18 )
ax.set_xlabel('Bairros',fontsize = 16)
ax.set_ylabel('Valor Médio dos Imóveis',fontsize = 16)

#ax.text(s ='Maior parte dos Imóveis estão com \n valor abaixo de 400 Milhões',x = 0.4, y = 600,
 #        horizontalalignment='center', size='medium', color='black', weight='semibold')

plt.ylim((1e7, 1.8e7))
plt.show()

# %%
valor_metro_bairro['preco_metro'] = valor_metro_bairro['Valor_Venda']/valor_metro_bairro['Metragem']

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_bar(x=valor_metro_bairro['Bairro'].values, y = valor_metro_bairro['preco_metro'].values)
fig.update_layout(
    autosize=False,
    width=1300,
    height=800
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dados_venda.to_csv('Dados_venda_Imersao4.csv',index = False)

# %% [markdown]
# ## Aula 03:
# <b>Objetivos:</b>
#
# 1. Ler dados IBGE
# 2. Juntar dados de vendas com do IBGE
# 3. Identificar os setores censitários de cada endereço

# %% [markdown]
# #### 1. Ler dados do IBGE e separar por cidade São Paulo

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
ibge_sp = pd.read_csv(ibge_url, sep =';', encoding = 'ISO-8859-1',thousands = '.',decimal = ',')

ibge_sp.dropna(how='all', axis=1, inplace=True)
ibge_sp.head()
ibge_sp.head(10)
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
# 5  355030801000006                      3   Regiï¿½o Sudeste      35
# 6  355030801000007                      3   Regiï¿½o Sudeste      35
# 7  355030801000008                      3   Regiï¿½o Sudeste      35
# 8  355030801000009                      3   Regiï¿½o Sudeste      35
# 9  355030801000010                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# ...

# %%
ibge_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
enderecos = pd.read_csv("/content/drive/MyDrive/Imersão_Dados_4/enderecos.csv")
enderecos.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning:
#
# Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
#          nome_localidade sigla_uf         cep   latitude  longitude
# ...

# %%
enderecos_sp = enderecos.query('sigla_uf == "SP"')
enderecos_sp.head()
# Out:
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# 413270       Rua                         A
# 413271       Rua                         A
# 413272       Rua              João Bandini
#
#                                         logr_compl numero  \
# 1       Rua João Antônio Vasconcelos - até 627/628    627
# 413269                                       Rua A    NaN
# 413270                                       Rua A    NaN
# 413271                                       Rua A    NaN
# 413272                            Rua João Bandini    NaN
#
#                         bairro nome_localidade sigla_uf         cep  \
# 1                      Amizade       Araçatuba       SP  16074320.0
# 413269           Jardim Glória       Americana       SP  13468220.0
# 413270        Jardim São Roque       Americana       SP  13469414.0
# 413271  Iate Clube de Campinas       Americana       SP  13475620.0
# ...

# %%
enderecos_sp['rua'] = enderecos_sp['tipo_logr']+ " "+ enderecos_sp['logr_nome']
enderecos_sp['rua'] = enderecos_sp['rua'].str.lower().str.strip()
enderecos_sp.head(8)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# 413270       Rua                         A
# 413271       Rua                         A
# ...

# %% [markdown]
# #### 2. Juntar dados de venda com endereços de SP
# Para fazer isso vamos realizar uma junção por rua. Desta forma teremos a Latitude e a Longitude das ruas para posteriormente conseguir analisar por Setor Censitário.

# %%
dados_venda["Rua"].str.extract(r'(^[\w ]+)')[:10]
# Out:
#                            0
# 0            Avenida Itacira
# 1  Rua Aurelia Perez Alvarez
# 2            Rua Alba Valdez
# 3                        NaN
# 4         Rua Tobias Barreto
# 5            Rua Graham Bell
# 6        Rua Francisco Paulo
# 7      Rua Guilherme Valente
# 8        Rua Sagrada Família
# 9                 Rua Tapaji

# %%
dados_venda['apenas_rua'] = dados_venda["Rua"].str.extract(r'(^[\w ]+)')
dados_venda["apenas_rua"] = dados_venda["apenas_rua"].str.lower().str.strip()
dados_venda.head(8)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# ...

# %%
dados_geo = pd.merge(left = dados_venda, right = enderecos_sp[["rua", "cep", "latitude", "longitude"]],
                     how = "left", left_on = "apenas_rua", right_on = "rua").drop_duplicates(subset=dados_venda.columns).query("cep > 0")
dados_geo.head(10)
# Out:
#                                Rua              Bairro     Cidade  Metragem  \
# 0            Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 5   Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 6                  Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 7                              NaN      Jardim Morumbi  São Paulo       310
# 26        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 39                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 40        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 41     Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 42         Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 44                      Rua Tapaji         Vila Alpina  São Paulo       114
#
#     Quartos  Banheiros  Vagas Moeda  Valor_Venda  Tipo  Valor_venda_escala  \
# ...

# %% [markdown]
# #### 3. Identificar o Setor Censitário
# Para identificar o Setor Censitário vamos utilizar o GeoPandas e uma sepração por polígonos. Para identificar o setor de cada endereços iremos identificar se o ponto (dado pela latitude e longitude) está dentro da área do polígono.

# %%
from shapely.geometry import Point
latitude = -23.56 	
longitude = -46.59
Point(longitude, latitude)

# %%
from shapely.geometry import Polygon
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])

# %%
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]]).contains(Point(0.1,0.9))
# Out:
# True

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd

# %%
setor_censo = gpd.read_file(
'/content/drive/MyDrive/Imersão_Dados_4/35SEE250GC_SIR.shp'
)
setor_censo.head()
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0  98237.0  354100005000009  URBANO  35410000500       None  354100005
# 1  98232.0  354100005000004  URBANO  35410000500       None  354100005
# 2  98230.0  354100005000002  URBANO  35410000500       None  354100005
# 3  98229.0  354100005000001  URBANO  35410000500       None  354100005
# 4  98231.0  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
setor_censo_sp = setor_censo[setor_censo.NM_MUNICIP == "SÃO PAULO"]
setor_censo_sp.head(10)
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 42322  109347.0  355030804000079  URBANO  35503080400       None  355030804
# 42323  109348.0  355030804000080  URBANO  35503080400       None  355030804
# 42324  109349.0  355030804000081  URBANO  35503080400       None  355030804
# 42325  109350.0  355030804000082  URBANO  35503080400       None  355030804
# 42326  109351.0  355030804000083  URBANO  35503080400       None  355030804
# 42327  109352.0  355030804000084  URBANO  35503080400       None  355030804
# 42328  109353.0  355030804000085  URBANO  35503080400       None  355030804
# 42329  109354.0  355030804000086  URBANO  35503080400       None  355030804
# 42330  109355.0  355030804000087  URBANO  35503080400       None  355030804
# 42331  109356.0  355030804000088  URBANO  35503080400       None  355030804
#
#        NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 42322  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# ...

# %%
setor_censo_sp[setor_censo_sp.contains(Point(-46.63, -23.58))]
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986  126568.0  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %%
dados_geo["Point"] = ""
for i in dados_geo.index:
    dados_geo["Point"][i] = Point(dados_geo["longitude"][i], dados_geo["latitude"][i])

dados_geo['setor_censo'] = dados_geo["Point"][:10].map(
    lambda x: setor_censo_sp.loc[setor_censo_sp.contains(x), 'CD_GEOCODI'].values
).str[0]
dados_geo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# ...

# %% [markdown]
# Abaixo vamos realizar a leitura dos dados para sobrepor os dados_geo, pois no arquivo abaixo há tratamentos realizados pelos instrutores.

# %%
dados_geo = pd.read_csv("/content/drive/MyDrive/Imersão_Dados_4/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000      7000000.0           NaN
# 1        4          4      4  R$ 3.700.000      3700000.0           NaN
# 2        4          3      2    R$ 380.000       380000.0           NaN
# 3        3          2      2    R$ 540.000       540000.0           NaN
# 4        4          4      6  R$ 1.980.000      1980000.0           NaN
#
#    Valor_mm     Valor_m2                        rua        cep   latitude  \
# ...

# %%
dados_vendas_censo = pd.merge(left = dados_geo, right = ibge_sp, how = "left", left_on = "setor_censo", right_on = "Cod_setor")
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5602                   Rua Guararema     Bosque da Saúde  São Paulo       605
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
dados_vendas_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_vendas_censo, x="V005", y="Valor_m2")

# %%
dados_vendas_censo.to_csv('dados_vendas_censo.csv')

# %% [markdown]
# Desafio
# 1 - Realizar uma análise dos dados do IBGE por mapa, analisando a distribuição de renda (https://medium.com/creditas-tech/dados-georreferenciados-explora%C3%A7%C3%A3o-e-visualiza%C3%A7%C3%A3o-com-python-edd51e7c53da)
#
# 2 - Repassar a aula para entender melhor o que foi realizado
#
# 3 - Aprofundar a análise entre dados de vendas e renda.
#
# 4 - Realizar a análise exploratória e encontrar variáveis relevantes para solução do problema.

# %% [markdown]
# #### 1. Análise dos dados de distribuição de renda do IBGE por mapa

# %%
setor_censo_sp.head()
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 42322  109347.0  355030804000079  URBANO  35503080400       None  355030804
# 42323  109348.0  355030804000080  URBANO  35503080400       None  355030804
# 42324  109349.0  355030804000081  URBANO  35503080400       None  355030804
# 42325  109350.0  355030804000082  URBANO  35503080400       None  355030804
# 42326  109351.0  355030804000083  URBANO  35503080400       None  355030804
#
#        NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 42322  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# 42323  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# 42324  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# 42325  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# 42326  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 42322  METROPOLITANA DE SÃO PAULO       None      None  42323
# 42323  METROPOLITANA DE SÃO PAULO       None      None  42324
# ...

# %%
setor_censo_sp.geometry[42325]

# %%
ax = setor_censo.plot()

# %%
import folium
from folium import Choropleth, Marker
from folium.plugins import MarkerCluster

# %%
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000      7000000.0           NaN
# 1        4          4      4  R$ 3.700.000      3700000.0           NaN
# 2        4          3      2    R$ 380.000       380000.0           NaN
# 3        3          2      2    R$ 540.000       540000.0           NaN
# 4        4          4      6  R$ 1.980.000      1980000.0           NaN
#
#    Valor_mm     Valor_m2                        rua        cep   latitude  \
# ...

# %%
center = [-23.54996, -46.588173]
# Create a map
m_stamem = folium.Map(location=center, 
                 width=500,height=500,
                 tiles='OpenStreetMap', zoom_start=12)

# Display the map
m_stamem
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
setor_censo_sp.columns
# Out:
# Index(['ID', 'CD_GEOCODI', 'TIPO', 'CD_GEOCODS', 'NM_SUBDIST', 'CD_GEOCODD',
#        'NM_DISTRIT', 'CD_GEOCODM', 'NM_MUNICIP', 'NM_MICRO', 'NM_MESO',
#        'CD_GEOCODB', 'NM_BAIRRO', 'ID1', 'geometry'],
#       dtype='object')

# %%
setor_censo_sp['centroid'] = setor_censo_sp['geometry'].apply(lambda z: (z.centroid.y, z.centroid.x))
setor_censo_sp.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 42322  109347.0  355030804000079  URBANO  35503080400       None  355030804
# 42323  109348.0  355030804000080  URBANO  35503080400       None  355030804
#
#        NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 42322  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# 42323  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 42322  METROPOLITANA DE SÃO PAULO       None      None  42323
# 42323  METROPOLITANA DE SÃO PAULO       None      None  42324
#
# ...

# %%
setor_censo_sp['CD_GEOCODI']
# Out:
# 42322    355030804000079
# 42323    355030804000080
# 42324    355030804000081
# 42325    355030804000082
# 42326    355030804000083
#               ...
# 62380    355030896000243
# 62381    355030896000244
# 62382    355030896000245
# 62383    355030896000246
# 62384    355030896000247
# Name: CD_GEOCODI, Length: 18953, dtype: object

# %%
dados_geo.columns
# Out:
# Index(['Rua', 'Bairro', 'Cidade', 'Metragem', 'Quartos', 'Banheiros', 'Vagas',
#        'Valor', 'Valor_anuncio', 'Tipo_anuncio', 'Valor_mm', 'Valor_m2', 'rua',
#        'cep', 'latitude', 'longitude', 'Point', 'setor_censo'],
#       dtype='object')

# %%
dados_geo['CD_GEOCODI'] = dados_geo['setor_censo']
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000      7000000.0           NaN
# 1        4          4      4  R$ 3.700.000      3700000.0           NaN
# 2        4          3      2    R$ 380.000       380000.0           NaN
# 3        3          2      2    R$ 540.000       540000.0           NaN
# 4        4          4      6  R$ 1.980.000      1980000.0           NaN
#
#    Valor_mm     Valor_m2                        rua        cep   latitude  \
# ...

# %%
setor_censo_sp.columns
# Out:
# Index(['ID', 'CD_GEOCODI', 'TIPO', 'CD_GEOCODS', 'NM_SUBDIST', 'CD_GEOCODD',
#        'NM_DISTRIT', 'CD_GEOCODM', 'NM_MUNICIP', 'NM_MICRO', 'NM_MESO',
#        'CD_GEOCODB', 'NM_BAIRRO', 'ID1', 'geometry', 'centroid'],
#       dtype='object')

# %%
# Cria o mapa
m_stamen_2 = folium.Map(location=center, 
                 tiles='Stamen Toner', zoom_start=12)

# Adiciona choropleth ao mapa
Choropleth(geo_data=setor_censo_sp.__geo_interface__, 
           data=dados_geo, 
           columns=['setor_censo', 'Valor_m2'],
           key_on="feature.properties.CD_GEOCODI", 
           fill_color='PuRd', 
           fill_opacity=0.5,
           legend_name='Renda Média'
          ).add_to(m_stamen_2)

# Mostra o mapa
m_stamen_2

# %% [markdown]
# Para saber mais:
# * https://medium.com/creditas-tech/dados-georreferenciados-exploração-e-visualização-com-python-edd51e7c53da
# ## Parte 5: Modelo de Machine Learning
# <b>Objetivos:</b>
# 1. Separar variáveis para usar no modelo
# 2. Realizar tratamentos no dataset a ser utilizados
# 3. Criar modelos

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set()

# %% [markdown]
# #### 1. Separando variáveis a usar no modelo

# %%
dados_vendas_censo = dados_vendas_censo[['Rua', 'Bairro', 'Cidade', 'Metragem', 'Quartos', 'Banheiros', 'Vagas',
       'Valor_anuncio', 'Valor_mm', 'Valor_m2', 'latitude', 'longitude', 'Situacao_setor', 'V001',
       'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008', 'V009', 'V010',
       'V011', 'V012']].dropna()
dados_vendas_censo.head(10)

# %% [markdown]
# #### 2. Tratamento básico
# * retirando alguns outliers no valor no anúncio
# * Analisando alguns comportamentos e correlações

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas_censo, y="Valor_anuncio")
plt.show()

# %%
dados_vendas_censo.drop(dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000").index, inplace = True)
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas_censo, y="Valor_anuncio")
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_vendas_censo, x="Valor_anuncio", y="Valor_m2")

# %%
#https://www.tylervigen.com/spurious-correlations
plt.figure(figsize=(18, 8))
mask = np.triu(np.ones_like(dados_vendas_censo.corr(), dtype=bool))
heatmap = sns.heatmap(dados_vendas_censo.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlação', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# #### 3. Primeiro modelo: Regressão Linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = dados_vendas_censo[["Metragem"]]
Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mean_absolute_error(Y_test, Y_predict_test)

# %%
mean_absolute_error(Y_train, Y_predict_train)

# %%
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros' ,'Vagas','V001','V007', 'V009']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

print(mae_test, r2_test, mae_train, r2_train)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_predict_test)

# %% [markdown]
# ##### Adicionando variável Valor por metro quadrado

# %%
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros','Valor_m2' ,'Vagas','V001','V007', 'V009']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

print(mae_test, r2_test, mae_train, r2_train)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_predict_test)

# %% [markdown]
# #### 2. Modelo 2: Regressão por SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'poly')

# %%
X = dados_vendas_censo[['Metragem', 'Quartos', 'Banheiros','Valor_m2' ,'Vagas','V001','V007', 'V009']]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
svr.fit(X_train, Y_train)
Y_predict_test = svr.predict(X_test)
Y_predict_train = svr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
print(mae_test, r2_test, mae_train, r2_train)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_predict_test)
